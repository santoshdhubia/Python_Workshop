# %% [markdown]
# # Example of Data Analysis with Python

# %%
# Import Required Libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns # Library for data visualization
# %matplotlib inline

sns.set(style="darkgrid")

# %% [markdown]
#     Load the Fortune 500 data-set in CSV file which contains rating of Forune 500 companies for 50 years from 1955

# %%
#df = pd.read_csv(r"C:\Users\santosh.d\Desktop\Fortune_500US.csv",encoding = 'ISO-8859-1')
df = pd.read_csv(r"C:\Users\santosh.d\Desktop\fortune50050.csv")

# %%
df
# Out:
#        Year  Rank                       Company  Revenue (in millions)  \
# 0      1955     1                General Motors                 9823.5
# 1      1955     2                   Exxon Mobil                 5661.4
# 2      1955     3                    U.S. Steel                 3250.4
# 3      1955     4              General Electric                 2959.1
# 4      1955     5                        Esmark                 2510.8
# 5      1955     6                      Chrysler                 2071.6
# 6      1955     7                        Armour                 2056.1
# 7      1955     8                      Gulf Oil                 1705.3
# 8      1955     9                         Mobil                 1703.6
# 9      1955    10                        DuPont                 1687.7
# 10     1955    11                         Amoco                 1667.4
# 11     1955    12               Bethlehem Steel                 1660.3
# 12     1955    13                           CBS                 1631.0
# 13     1955    14                        Texaco                 1574.4
# 14     1955    15             AT&T Technologies                 1526.2
# 15     1955    16                     Shell Oil                 1312.1
# 16     1955    17                         Kraft                 1210.3
# 17     1955    18                 ChevronTexaco                 1113.3
# 18     1955    19        Goodyear Tire & Rubber                 1090.1
# 19     1955    20                        Boeing                 1033.2
# 20     1955    21                  Sinclair Oil                 1021.5
# 21     1955    22        Navistar International                  994.1
# 22     1955    23                           RCA                  941.0
# 23     1955    24                 Union Carbide                  923.7
# 24     1955    25       Firestone Tire & Rubber                  916.0
# 25     1955    26              Douglas Aircraft                  915.2
# 26     1955    27              Procter & Gamble                  911.0
# 27     1955    28                Republic Steel                  846.3
# 28     1955    29               Citgo Petroleum                  813.2
# 29     1955    30                ConocoPhillips                  794.6
# ...     ...   ...                           ...                    ...
# 25470  2005   471              Wisconsin Energy                 3912.1
# 25471  2005   472       American Financial Grp.                 3911.7
# 25472  2005   473              Beazer Homes USA                 3907.1
# 25473  2005   474              Collins & Aikman                 3904.0
# 25474  2005   475                 Borders Group                 3903.0
# 25475  2005   476                    Nash Finch                 3897.1
# 25476  2005   477                 Toll Brothers                 3893.1
# 25477  2005   478                         SCANA                 3885.0
# 25478  2005   479            Whole Foods Market                 3864.9
# 25479  2005   480                       Corning                 3854.0
# 25480  2005   481                    Sealed Air                 3798.1
# 25481  2005   482                        Maxtor                 3796.3
# 25482  2005   483          Reebok International                 3785.3
# 25483  2005   484                           UGI                 3784.7
# 25484  2005   485                       Guidant                 3775.2
# 25485  2005   486                 Host Marriott                 3773.0
# 25486  2005   487            Advance Auto Parts                 3770.3
# 25487  2005   488                 ServiceMaster                 3759.6
# 25488  2005   489           Wesco International                 3741.3
# 25489  2005   490         Telephone & Data Sys.                 3720.4
# 25490  2005   491        Level 3 Communications                 3712.0
# 25491  2005   492         Brinker International                 3707.5
# 25492  2005   493         Stater Bros. Holdings                 3704.9
# 25493  2005   494  Western & Southern Financial                 3694.5
# 25494  2005   495                       Gateway                 3649.7
# 25495  2005   496               Wm. Wrigley Jr.                 3648.6
# 25496  2005   497                Peabody Energy                 3631.6
# 25497  2005   498         Wendy's International                 3630.4
# 25498  2005   499            Kindred Healthcare                 3616.6
# 25499  2005   500          Cincinnati Financial                 3614.0
#
#       Profit (in millions)
# 0                      806
# 1                    584.8
# 2                    195.4
# 3                    212.6
# 4                     19.1
# 5                     18.5
# 6                      1.6
# 7                    182.8
# 8                    183.8
# 9                    344.4
# 10                   132.8
# 11                   117.2
# 12                    84.6
# 13                   226.1
# 14                    55.8
# 15                   121.1
# 16                    37.4
# 17                   211.9
# 18                    48.1
# 19                      37
# 20                    91.6
# 21                    36.3
# 22                    40.5
# 23                    89.8
# 24                    40.5
# 25                    36.2
# 26                    52.3
# 27                    52.9
# 28                    43.7
# 29                    76.2
# ...                    ...
# 25470                306.4
# 25471                359.9
# 25472                235.8
# 25473               -118.5
# 25474                131.9
# 25475                 14.9
# 25476                409.1
# 25477                  257
# 25478                137.1
# 25479                -2165
# 25480                215.6
# 25481               -181.9
# 25482                192.4
# 25483                111.6
# 25484                  524
# 25485                 N.A.
# 25486                  188
# 25487                331.2
# 25488                 64.9
# 25489                   49
# 25490                 -458
# 25491                  154
# 25492                 71.8
# 25493                  328
# 25494               -567.6
# 25495                  493
# 25496                175.4
# 25497                 57.8
# 25498                 70.6
# 25499                  584
#
# [25500 rows x 5 columns]

# %%
df.head() #print first 5 values
# Out:
#    Year  Rank           Company  Revenue (in millions) Profit (in millions)
# 0  1955     1    General Motors                 9823.5                  806
# 1  1955     2       Exxon Mobil                 5661.4                584.8
# 2  1955     3        U.S. Steel                 3250.4                195.4
# 3  1955     4  General Electric                 2959.1                212.6
# 4  1955     5            Esmark                 2510.8                 19.1

# %%
df.tail() #print last 5 values
# Out:
#        Year  Rank                Company  Revenue (in millions)  \
# 25495  2005   496        Wm. Wrigley Jr.                 3648.6
# 25496  2005   497         Peabody Energy                 3631.6
# 25497  2005   498  Wendy's International                 3630.4
# 25498  2005   499     Kindred Healthcare                 3616.6
# 25499  2005   500   Cincinnati Financial                 3614.0
#
#       Profit (in millions)
# 25495                  493
# 25496                175.4
# 25497                 57.8
# 25498                 70.6
# 25499                  584

# %% [markdown]
# # To have better control on colloumns we will change the name of the colloumns by removing special characters and spaces

# %%
#df.columns = ['rank', 'company', 'Employee', 'PrevRanK', 'Revenues','RevenueChange', 'Profits', 'ProfitChange', 'Assets', 'MarketVale']
df.columns = ['year', 'rank','company','revenue','profit']

# %%
df.head()
# Out:
#    year  rank           company  revenue profit
# 0  1955     1    General Motors   9823.5    806
# 1  1955     2       Exxon Mobil   5661.4  584.8
# 2  1955     3        U.S. Steel   3250.4  195.4
# 3  1955     4  General Electric   2959.1  212.6
# 4  1955     5            Esmark   2510.8   19.1

# %%
df.dtypes
# Out:
# year         int64
# rank         int64
# company     object
# revenue    float64
# profit      object
# dtype: object

# %% [markdown]
# # Clean the data-set

# %%
df1=df
#df1=~df.profit.str.contains('N.A.')
df1=df.profit.str.contains("[0-9]+")
df2=df[df1] # copy with numerical values in profit colooumn
df_missing=df[~df1]
df2
# Out:
#        year  rank                       company  revenue  profit
# 0      1955     1                General Motors   9823.5     806
# 1      1955     2                   Exxon Mobil   5661.4   584.8
# 2      1955     3                    U.S. Steel   3250.4   195.4
# 3      1955     4              General Electric   2959.1   212.6
# 4      1955     5                        Esmark   2510.8    19.1
# 5      1955     6                      Chrysler   2071.6    18.5
# 6      1955     7                        Armour   2056.1     1.6
# 7      1955     8                      Gulf Oil   1705.3   182.8
# 8      1955     9                         Mobil   1703.6   183.8
# 9      1955    10                        DuPont   1687.7   344.4
# 10     1955    11                         Amoco   1667.4   132.8
# 11     1955    12               Bethlehem Steel   1660.3   117.2
# 12     1955    13                           CBS   1631.0    84.6
# 13     1955    14                        Texaco   1574.4   226.1
# 14     1955    15             AT&T Technologies   1526.2    55.8
# 15     1955    16                     Shell Oil   1312.1   121.1
# 16     1955    17                         Kraft   1210.3    37.4
# 17     1955    18                 ChevronTexaco   1113.3   211.9
# 18     1955    19        Goodyear Tire & Rubber   1090.1    48.1
# 19     1955    20                        Boeing   1033.2      37
# 20     1955    21                  Sinclair Oil   1021.5    91.6
# 21     1955    22        Navistar International    994.1    36.3
# 22     1955    23                           RCA    941.0    40.5
# 23     1955    24                 Union Carbide    923.7    89.8
# 24     1955    25       Firestone Tire & Rubber    916.0    40.5
# 25     1955    26              Douglas Aircraft    915.2    36.2
# 26     1955    27              Procter & Gamble    911.0    52.3
# 27     1955    28                Republic Steel    846.3    52.9
# 28     1955    29               Citgo Petroleum    813.2    43.7
# 29     1955    30                ConocoPhillips    794.6    76.2
# ...     ...   ...                           ...      ...     ...
# 25469  2005   470          Cooper Tire & Rubber   3933.6   201.4
# 25470  2005   471              Wisconsin Energy   3912.1   306.4
# 25471  2005   472       American Financial Grp.   3911.7   359.9
# 25472  2005   473              Beazer Homes USA   3907.1   235.8
# 25473  2005   474              Collins & Aikman   3904.0  -118.5
# 25474  2005   475                 Borders Group   3903.0   131.9
# 25475  2005   476                    Nash Finch   3897.1    14.9
# 25476  2005   477                 Toll Brothers   3893.1   409.1
# 25477  2005   478                         SCANA   3885.0     257
# 25478  2005   479            Whole Foods Market   3864.9   137.1
# 25479  2005   480                       Corning   3854.0   -2165
# 25480  2005   481                    Sealed Air   3798.1   215.6
# 25481  2005   482                        Maxtor   3796.3  -181.9
# 25482  2005   483          Reebok International   3785.3   192.4
# 25483  2005   484                           UGI   3784.7   111.6
# 25484  2005   485                       Guidant   3775.2     524
# 25486  2005   487            Advance Auto Parts   3770.3     188
# 25487  2005   488                 ServiceMaster   3759.6   331.2
# 25488  2005   489           Wesco International   3741.3    64.9
# 25489  2005   490         Telephone & Data Sys.   3720.4      49
# 25490  2005   491        Level 3 Communications   3712.0    -458
# 25491  2005   492         Brinker International   3707.5     154
# 25492  2005   493         Stater Bros. Holdings   3704.9    71.8
# 25493  2005   494  Western & Southern Financial   3694.5     328
# 25494  2005   495                       Gateway   3649.7  -567.6
# 25495  2005   496               Wm. Wrigley Jr.   3648.6     493
# 25496  2005   497                Peabody Energy   3631.6   175.4
# 25497  2005   498         Wendy's International   3630.4    57.8
# 25498  2005   499            Kindred Healthcare   3616.6    70.6
# 25499  2005   500          Cincinnati Financial   3614.0     584
#
# [25131 rows x 5 columns]

# %% [markdown]
# # Plot the histogram of the missing values in Profit Coloumn year wise

# %%
bins = plt.hist(df_missing.year, bins=range(1955, 2006))

# %% [markdown]
# # Create a year-wise group to calculate mean profite and revenues

# %%
df2.profit=df2.profit.apply(pd.to_numeric)
df_grouped=df2.loc[:,:].groupby('year')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py:4405: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[name] = value

# %%
df_grouped.size()
# Out:
# year
# 1955    494
# 1956    498
# 1957    497
# 1958    497
# 1959    497
# 1960    499
# 1961    498
# 1962    498
# 1963    500
# 1964    500
# 1965    499
# 1966    500
# 1967    500
# 1968    500
# 1969    500
# 1970    500
# 1971    493
# 1972    492
# 1973    493
# 1974    493
# 1975    494
# 1976    493
# 1977    493
# 1978    491
# 1979    491
# 1980    493
# 1981    492
# 1982    490
# 1983    491
# 1984    489
# 1985    487
# 1986    477
# 1987    477
# 1988    480
# 1989    476
# 1990    481
# 1991    480
# 1992    479
# 1993    484
# 1994    484
# 1995    494
# 1996    494
# 1997    496
# 1998    497
# 1999    497
# 2000    496
# 2001    497
# 2002    496
# 2003    495
# 2004    500
# 2005    499
# dtype: int64

# %%
def myplot(x,y,x_label,y_label,title):
    plt.plot(x,y)
    plt.xlabel(x_label)
    plt.ylabel(y_label)
    plt.legend()
    plt.title(title)
    plt.show()

#plt.plot(df_grouped.revenue.std(),df_grouped.profit.std())

# %%
myplot(df_grouped.revenue.std(),df_grouped.profit.std(),"Revenue Standard Deviation","Profit Standard Deviation","abc")

# %% [markdown]
# # Plot with Myplot Function

# %%
x_label="Revenue Standard Deviation"
y_label="Profit Standard Deviation"
title="Revenue vs Profit (Standard DEviation)"
myplot(df_grouped.revenue.std(),df_grouped.profit.std(),x_label,y_label,title)

# %%
x_label="Year"
y_label="Profit Mean"
title="Profit (Mean)"
myplot(df_grouped.mean().index,df_grouped.profit.mean(),x_label,y_label,title)

# %%
df_group_company=df2.loc[:,:].groupby('company')

# %% [markdown]
# # Get slice of data frame for a company say - General Motors

# %%
df_GM=df_group_company.get_group('General Motors')
df_GM
# Out:
#        year  rank         company   revenue   profit
# 0      1955     1  General Motors    9823.5    806.0
# 500    1956     1  General Motors   12443.3   1189.5
# 1000   1957     1  General Motors   10796.4    847.4
# 1500   1958     1  General Motors   10989.8    843.6
# 2000   1959     1  General Motors    9522.0    633.6
# 2500   1960     1  General Motors   11233.1    873.1
# 3000   1961     1  General Motors   12736.0    959.0
# 3500   1962     1  General Motors   11395.9    892.8
# 4000   1963     1  General Motors   14640.2   1459.1
# 4500   1964     1  General Motors   16494.8   1591.8
# 5000   1965     1  General Motors   16997.0   1734.8
# 5500   1966     1  General Motors   20734.0   2125.6
# 6000   1967     1  General Motors   20208.5   1793.4
# 6500   1968     1  General Motors   20026.3   1627.3
# 7000   1969     1  General Motors   22755.4   1731.9
# 7500   1970     1  General Motors   24295.1   1710.7
# 8000   1971     1  General Motors   18752.4    609.1
# 8500   1972     1  General Motors   28263.9   1935.7
# 9000   1973     1  General Motors   30435.2   2162.8
# 9500   1974     1  General Motors   35798.3   2398.1
# 10001  1975     2  General Motors   31549.5    950.1
# 10501  1976     2  General Motors   35724.9   1253.1
# 11001  1977     2  General Motors   47181.0   2902.8
# 11500  1978     1  General Motors   54961.3   3337.5
# 12000  1979     1  General Motors   63221.1   3508.0
# 12501  1980     2  General Motors   66311.2   2892.7
# 13002  1981     3  General Motors   57728.5   -762.5
# 13502  1982     3  General Motors   62698.5    333.4
# 14001  1983     2  General Motors   60025.6    962.7
# 14501  1984     2  General Motors   74581.6   3730.2
# 15001  1985     2  General Motors   83889.9   4516.5
# 15500  1986     1  General Motors   96371.7   3999.0
# 16000  1987     1  General Motors  102813.7   2944.7
# 16500  1988     1  General Motors  101782.0   3551.0
# 17000  1989     1  General Motors  121085.0   4856.0
# 17500  1990     1  General Motors  126974.3   4224.3
# 18000  1991     1  General Motors  125126.0  -1985.7
# 18500  1992     1  General Motors  123780.1  -4452.8
# 19000  1993     1  General Motors  132774.9 -23498.3
# 19500  1994     1  General Motors  133621.9   2465.8
# 20000  1995     1  General Motors  154951.2   4900.6
# 20500  1996     1  General Motors  168828.6   6880.7
# 21000  1997     1  General Motors  168369.0   4963.0
# 21500  1998     1  General Motors  178174.0   6698.0
# 22000  1999     1  General Motors  161315.0   2956.0
# 22500  2000     1  General Motors  189058.0   6002.0
# 23002  2001     3  General Motors  184632.0   4452.0
# 23502  2002     3  General Motors  177260.0    601.0
# 24001  2003     2  General Motors  186763.0   1736.0
# 24502  2004     3  General Motors  195645.2   3822.0
# 25002  2005     3  General Motors  193517.0   2805.0

# %% [markdown]
# # Plot the Revenue and Proift vs Years for General Motors

# %%
x_label="Year"
y_label="Profit"
title="Yearly Profit of GM from 1995 to 2005"
myplot(df_GM.year,df_GM.profit,x_label,y_label,title)

# %%
x_label="Year"
y_label="Revenue"
title="Yearly Revenue of GM from 1995 to 2005"
myplot(df_GM.year,df_GM.revenue,x_label,y_label,title)

# %% [markdown]
# # Plotting Side by Side

# %%
x_label="Year"
y_label="Revenue"
title="Yearly Revenue of GM from 1995 to 2005"
myplot(df_GM.year,df_GM.revenue,x_label,y_label,title)

x_label="Year"
y_label="Profit"
title="Yearly Profit of GM from 1995 to 2005"
myplot(df_GM.year,df_GM.profit,x_label,y_label,title)

# %% [markdown]
# # Create a new df for company - "Exxon Mobil" and make comparative plots  with GM
