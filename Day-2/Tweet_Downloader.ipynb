# %%
import numpy as np      
import tweepy           
import pandas as pd     

import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

import config # import access and security tokens

# %%
def twitter_api_setup():
    authentication = tweepy.OAuthHandler(config.consumer_key, config.consumer_secret)
    authentication.set_access_token(config.access_token, config.access_secret)
    api = tweepy.API(authentication)
    return api

# %%
Tweet_Downloader = twitter_api_setup()

# %%
tweets = Tweet_Downloader.user_timeline(screen_name="EconomicTimes", count=200)

# %%
print("Number of tweets downloaded: {}.\n".format(len(tweets)))
# Out:
# Number of tweets downloaded: 200.

# %%
for tweet in tweets:
    print(tweet.text)
    print()
# Out:
# RT @ET_RISE: Our government implemented #GST which is undoubtedly the biggest reform taken by the government: Union Finance Minister @Piyus…
#
# RT @ETDefence: #IndianAirForce's #Mirage2000 crashes in #Bengaluru
#
# #IAF #HAL
#
# Story updated with IAF statement:  Both occupants sustained…
#
# @PiyushGoyal #BudgET2019: Govt increases allocation for north eastern states to 21%: FM @PiyushGoyal |… https://t.co/ZG6BwXHosQ
#
# RT @ET_Wealth: #BudgetWithET #BudgET2019 #BudgetSession @FinMinIndia @PiyushGoyal https://t.co/Iwg1ZywAEx
#
# #BudgET2019 | FM Piyush Goyal said India has emerged as the brightest spot in the world in the last five years duri… https://t.co/uxqJfcb6gp
#
# @PiyushGoyal #ECONOMICS OF THIS #BUDGET
# » India’s current account deficit for 2018/19 seen at 2.5 pct of GDP
# » Fis… https://t.co/l4X5U43J4Z
#
# @PiyushGoyal #BudgET2019: Loans worth Rs 7.23 lakh cr have been given under #MudraYojana: FM @PiyushGoyal |… https://t.co/iKfEoC0M0x
#
# ...

# %% [markdown]
# # Convert tweets to dataframe and save to csv file

# %%
data = pd.DataFrame(data=[tweet.text for tweet in tweets], columns=['Tweets'])

# %%
data
# Out:
#                                                 Tweets
# 0    RT @ET_RISE: Our government implemented #GST w...
# 1    RT @ETDefence: #IndianAirForce's #Mirage2000 c...
# 2    @PiyushGoyal #BudgET2019: Govt increases alloc...
# 3    RT @ET_Wealth: #BudgetWithET #BudgET2019 #Budg...
# 4    #BudgET2019 | FM Piyush Goyal said India has e...
# 5    @PiyushGoyal #ECONOMICS OF THIS #BUDGET\n» Ind...
# 6    @PiyushGoyal #BudgET2019: Loans worth Rs 7.23 ...
# 7    #BudgET2019 | Interim Finance Minister Piyush ...
# 8    @PiyushGoyal #BudgET2019: #Defence #budget inc...
# 9    @PiyushGoyal #BudgET2019: 26 weeks of maternit...
# 10   @PiyushGoyal #BudgET2019: FM announces 8 crore...
# 11   @PiyushGoyal #BudgET2019: In place of reschedu...
# 12   .@TataSky seeks new partners as financial spon...
# 13   @PiyushGoyal #BudgET2019: Increased allocation...
# 14   @PiyushGoyal #BudgET2019: To provide assured i...
# 15   @PiyushGoyal #BudgET2019: Pace of construction...
# ...

# %%
tweets[0]
# Out:
# Status(_api=<tweepy.api.API object at 0x000000682889BC50>, _json={'created_at': 'Fri Feb 01 06:48:59 +0000 2019', 'id': 1091226891057532928, 'id_str': '1091226891057532928', 'text': 'RT @ET_RISE: Our government implemented #GST which is undoubtedly the biggest reform taken by the government: Union Finance Minister @Piyus…', 'truncated': False, 'entities': {'hashtags': [{'text': 'GST', 'indices': [40, 44]}], 'symbols': [], 'user_mentions': [{'screen_name': 'ET_RISE', 'name': 'ET RISE', 'id': 3188580042, 'id_str': '3188580042', 'indices': [3, 11]}], 'urls': []}, 'source': '<a href="https://about.twitter.com/products/tweetdeck" rel="nofollow">TweetDeck</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 39743812, 'id_str': '39743812', 'name': 'EconomicTimes', 'screen_name': 'EconomicTimes', 'location': '', 'description': "India's No. 1 Business Daily that bri
# ...

# %%
dir(tweets[0])
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_api',
#  '_json',
#  'author',
#  'contributors',
#  'coordinates',
#  'created_at',
#  'destroy',
#  'entities',
#  'favorite',
#  'favorite_count',
#  'favorited',
#  'geo',
#  'id',
#  'id_str',
#  'in_reply_to_screen_name',
#  'in_reply_to_status_id',
#  'in_reply_to_status_id_str',
#  'in_reply_to_user_id',
#  'in_reply_to_user_id_str',
#  'is_quote_status',
#  'lang',
#  'parse',
#  'parse_list',
#  'place',
#  'retweet',
#  'retweet_count',
#  'retweeted',
#  'retweeted_status',
#  'retweets',
#  'source',
#  'source_url',
#  'text',
# ...

# %%
print(tweets[199].source)
# Out:
# Twitter Media Studio

# %%
# Add Relevant Data-set to yout DataFram
data['len']  = np.array([len(tweet.text) for tweet in tweets])
data['ID']   = np.array([tweet.id for tweet in tweets])
data['Date'] = np.array([tweet.created_at for tweet in tweets])
data['Source'] = np.array([tweet.source for tweet in tweets])
data['Likes']  = np.array([tweet.favorite_count for tweet in tweets])
data['RTs']    = np.array([tweet.retweet_count for tweet in tweets])
data['coordinates'] = np.array([tweet.coordinates for tweet in tweets])
data['Lang']    = np.array([tweet.lang for tweet in tweets])

# %%
data
# Out:
#                                                 Tweets  len  \
# 0    RT @ET_RISE: Our government implemented #GST w...  140
# 1    RT @ETDefence: #IndianAirForce's #Mirage2000 c...  139
# 2    @PiyushGoyal #BudgET2019: Govt increases alloc...  127
# 3    RT @ET_Wealth: #BudgetWithET #BudgET2019 #Budg...  105
# 4    #BudgET2019 | FM Piyush Goyal said India has e...  140
# 5    @PiyushGoyal #ECONOMICS OF THIS #BUDGET\n» Ind...  140
# 6    @PiyushGoyal #BudgET2019: Loans worth Rs 7.23 ...  132
# 7    #BudgET2019 | Interim Finance Minister Piyush ...  140
# 8    @PiyushGoyal #BudgET2019: #Defence #budget inc...  133
# 9    @PiyushGoyal #BudgET2019: 26 weeks of maternit...  140
# 10   @PiyushGoyal #BudgET2019: FM announces 8 crore...  140
# 11   @PiyushGoyal #BudgET2019: In place of reschedu...  140
# 12   .@TataSky seeks new partners as financial spon...  111
# 13   @PiyushGoyal #BudgET2019: Increased allocation...  128
# 14   @PiyushGoyal #BudgET2019: To provide assured i...  140
# ...

# %%
#data.to_csv(r"C:\Users\santosh.d\Desktop\ET_tweets", encoding='utf8')

# %% [markdown]
# # Download tweets by Hashtag

# %%
tweets_hashtag = Tweet_Downloader.search('Budget2019', lang='en',count=300)

# %%
#for tweet in tweets_hashtag:
#    print(tweet.text)
#    print()

# %%
data_hs = pd.DataFrame(data=[tweet.text for tweet in tweets_hashtag], columns=['Tweets'])
len(data_hs)
# Out:
# 100

# %%
data_hs['len']  = np.array([len(tweet.text) for tweet in tweets_hashtag])
data_hs['ID']   = np.array([tweet.id for tweet in tweets_hashtag])
data_hs['Date'] = np.array([tweet.created_at for tweet in tweets_hashtag])
data_hs['Source'] = np.array([tweet.source for tweet in tweets_hashtag])
data_hs['Likes']  = np.array([tweet.favorite_count for tweet in tweets_hashtag])
data_hs['RTs']    = np.array([tweet.retweet_count for tweet in tweets_hashtag])
data_hs['coordinates'] = np.array([tweet.coordinates for tweet in tweets_hashtag])
data_hs['Lang']    = np.array([tweet.lang for tweet in tweets_hashtag])

# %%
data_hs
# Out:
#                                                Tweets  len  \
# 0   During tax budget announcement all tv anchor ,...  140
# 1   RT @Atheist_Krishna: This is what Piyush Goyal...  111
# 2   #Budget2019 #BudgetSession2019 \nEvery great i...  140
# 3   RT @SuPriyoBabul: 3 lakh crore allocated for D...  136
# 4   RT @Sassy_Soul_: If "kyun chaunk gaye na ?" ha...   91
# 5   RT @_YogendraYadav: #Budget2019 actually rubs ...  140
# 6   Middle Class after #Budget2019\n#BudgetForNewI...   73
# 7   RT @Atheist_Krishna: Middle class salaried peo...  116
# 8   RT @INCIndia: PM Modi can make all the grand a...  140
# 9   RT @kajal_jaihind: #Budget2019: Tax collection...  140
# 10      How is the JOSH middle class??\n\n#Budget2019   43
# 11  RT @abhijitmajumder: Casteless quota and a bum...  139
# 12  RT @Ra_THORe: From small and marginal farmers ...  140
# 13  RT @RatanSharda55: I propose an amendment to t...  140
# 14  @palkisu @WIONews Accidental PM, URI aur budge...  140
# ...

# %%
data_hs.to_csv(r"C:\Users\santosh.d\Desktop\Budgte_2019_tweets", encoding='utf8')
