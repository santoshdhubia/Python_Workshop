# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from wordcloud import WordCloud, STOPWORDS
from scipy.misc import imread
import re

# %matplotlib inline

# %%
text = []
for line in open(r'C:\Users\santosh.d\Desktop\about_pdpu.txt'):
    text.append(line.strip())

# %%
#Tweet_mask = imread(r"C:\Users\santosh.d\Desktop\twitter_mask.png", flatten=True)
wcloud = WordCloud(background_color="white", stopwords=STOPWORDS)
wcloud.generate(str(text))

# %%
plt.figure( figsize=(20,10))
plt.imshow(wcloud)
plt.axis('off')
#plt.savefig(r"C:\Users\santosh.d\Desktop\wordcloud_HS.png",dpi=300)
plt.show()
